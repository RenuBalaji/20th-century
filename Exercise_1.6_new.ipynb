# %%
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 5.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.3)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Initialize the model
NER = spacy.load("en_core_web_sm")

# Test the model
doc = NER("This is a test sentence.")
for token in doc:
    print(token.text, token.pos_)
# Out:
# This PRON
# is AUX
# a DET
# test NOUN
# sentence NOUN
# . PUNCT

# %%
# Open and read a text file
file_path = r'/Users/renubalaji/Documents/GitHubProjects/20th-century/key_events_20th_century.txt'

with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# Display the first few lines of the text
print(text[:500])  # Display the first 500 characters
# Out:
# Contents
# Historic events in the 20th century
# World at the beginning of the century
# Between the wars
# Global war: World War II (1939–1945)
# The post-war world
# The world at the end of the century
# See also
# References
# Sources
# External links
#
# The 20th century changed the world in unprecedented ways. The World Wars sparked tension between countries and led to the creation of atomic bombs, the Cold War led to the Space Race and the creation of space-based rockets, and the World Wide Web was created. Thes

# %% [markdown]
# # Creating a NER object

# %%
book = NER(text)

# %%
displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">movement. This was similar to how the 9/11 was the inciting incident of the 21st century.[1] Bound by
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Slavic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  nationalism to help the small
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serbian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  state, the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  came to the aid of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serbs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  when they were attacked.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Interwoven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  alliances, an increasing arms race, and old hatreds dragged
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  into the war.[2] The Allies, known initially as &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Triple Entente
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot;, comprised
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the British Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria-Hungary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bulgaria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and later
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ottoman Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , were known as &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Central Powers&quot;.[3][4]
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ended hostile actions against
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  after the fall of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tsar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bolsheviks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  negotiated
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Treaty of Brest-Litovsk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , although it was a huge cost to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In the treaty,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bolshevik Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ceded the
# <mark class="entity" style="back

# %% [markdown]
# # Splitting the sentence entities

# %%
df_sentences = []

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.0.3-cp38-cp38-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.1 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.20.3 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/20th_century/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.0.3-cp38-cp38-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 5.1 MB/s eta 0:00:00a 0:00:01
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.0.3 tzdata-2024.2

# %%
import pandas as pd
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence":sent, "entities":entity_list})
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (Contents, \n, Historic, events, in, the, 20th...
# 1  (The, World, Wars, sparked, tension, between, ...
# 2  (These, advancements, have, played, a, signifi...
# 3  (The, new, beginning, of, the, 20th, century, ...
# 4  (The, 1900s, saw, the, decade, herald, a, seri...
# 5  (From, 1914, to, 1918, ,, the, First, World, W...
# 6  (The, First, World, War, (, or, simply, WWI, )...
# 7  (The, war, and, by, extension, the, century, a...
# 8  (This, was, similar, to, how, the, 9/11, was, ...
# 9                                    (century.[1, ])
#
#                                             entities
# 0  [the 20th century, the beginning of the centur...
# 1  [the Cold War, the Space Race, the World Wide ...
# 2                          [the 21st century, today]
# 3                                 [the 20th century]
# 4                            [The 1900s, the decade]
# 5                [1914 to 1918, the First World War]
# 6   [The First World War, The Great War, 1914, 1918]
# 7  [the century, Sarajevo, the Austro-Hungarian E...
# 8                                                 []
# 9                                                 []

# %% [markdown]
# # Filter data using the Main characters

# %%
def filter_entity(ent_list, character_df):
    # Your function logic here
    filtered_entities = [ent for ent in ent_list if ent in character_df['character'].values]
    return filtered_entities

# %%
print(df_sentences.columns)
# Out:
# Index(['sentence', 'entities'], dtype='object')

# %%
def filter_entity(ent_list, character_df):
    """
    Filters the entities from ent_list based on whether they appear in character_df['character'].

    Args:
        ent_list (list): A list of entities to filter.
        character_df (pd.DataFrame): A DataFrame containing a 'character' column with valid entities.

    Returns:
        list: A list of entities that match with those in the character DataFrame.
    """
    # Filter entities that exist in the character DataFrame
    filtered_entities = [ent for ent in ent_list if ent in character_df['character'].values]
    return filtered_entities

# Example usage:

# Assuming ent_list contains the extracted entities (strings)
ent_list = ["Germany", "France", "Einstein", "Russia", "Japan"]

# Assuming character_df is a DataFrame containing valid characters (including countries)
data = {'character': ["Germany", "Russia", "France", "Japan", "Italy"]}
character_df = pd.DataFrame(data)

# Filter the entities
filtered_result = filter_entity(ent_list, character_df)
print(filtered_result)
# Out:
# ['Germany', 'France', 'Russia', 'Japan']

# %%
path = os.path.join(os.path.expanduser("~"), "relationships.csv")

# Try saving the file with error handling
try:
    df_sentences.to_csv(path, index=False)
    print(f"DataFrame created and saved at {path}.")
except Exception as e:
    print(f"Error saving the file: {e}")
# Out:
# DataFrame created and saved at /Users/renubalaji/relationships.csv.

# %% [markdown]
# # Create the relationships dataframe

# %%
countries_df = pd.read_csv("countries_20th_century.csv", index_col = 0)

# %%
countries_df.head()
# Out:
#     country_name
# 1   Afghanistan
# 2       Albania
# 3       Algeria
# 4       Andorra
# 5        Angola

# %%
countries_df.dtypes
# Out:
# country_name    object
# dtype: object

# %%
countries_df['country_name'].to_list
# Out:
# <bound method IndexOpsMixin.tolist of 1                              Afghanistan
# 2                                  Albania
# 3                                  Algeria
# 4                                  Andorra
# 5                                   Angola
#                        ...
# 205       Sahrawi Arab Democratic Republic
# 206                             Somaliland
# 207                          South Ossetia
# 208                                 Taiwan
# 209                            Transnistria
# Name: country_name, Length: 209, dtype: object>

# %%
countries_df['country_name'] = countries_df['country_name'].str.strip().str.lower()

# %%
countries_df['country_name'].to_list
# Out:
# <bound method IndexOpsMixin.tolist of 1                           afghanistan
# 2                               albania
# 3                               algeria
# 4                               andorra
# 5                                angola
#                      ...
# 205    sahrawi arab democratic republic
# 206                          somaliland
# 207                       south ossetia
# 208                              taiwan
# 209                        transnistria
# Name: country_name, Length: 209, dtype: object>

# %%
def filter_entity(ent_list, countries_df):
    cleaned_countries = countries_df['country_name'].to_list()
    return [ent.strip().lower() for ent in ent_list if ent.strip().lower() in cleaned_countries]

# %%
df_sentences['character_entity'] = df_sentences['entities'].apply(lambda x: filter_entity(x, countries_df))

# %%
df_sentences.head()
# Out:
#                                             sentence  \
# 0  (Contents, \n, Historic, events, in, the, 20th...
# 1  (The, World, Wars, sparked, tension, between, ...
# 2  (These, advancements, have, played, a, signifi...
# 3  (The, new, beginning, of, the, 20th, century, ...
# 4  (The, 1900s, saw, the, decade, herald, a, seri...
#
#                                             entities character_entity
# 0  [the 20th century, the beginning of the centur...               []
# 1  [the Cold War, the Space Race, the World Wide ...               []
# 2                          [the 21st century, today]               []
# 3                                 [the 20th century]               []
# 4                            [The 1900s, the decade]               []

# %%
def x(x):
    if len(x) > 0:
        return x

# %%
df_sentences_filtered = df_sentences[df_sentences['character_entity'].apply (lambda x: len(x) > 0)]

# %%
df_sentences_filtered
# Out:
#                                               sentence  \
# 12   (The, Allies, ,, known, initially, as, ", The,...
# 13   (Germany, ,, Austria, -, Hungary, ,, Bulgaria,...
# 14   (In, 1917, ,, Russia, ended, hostile, actions,...
# 15   (The, Bolsheviks, negotiated, the, Treaty, of,...
# 16   (In, the, treaty, ,, Bolshevik, Russia, ceded,...
# ..                                                 ...
# 263  (This, was, obviously, disquieting, to, the, U...
# 265  (After, a, tense, week, ,, the, Soviet, Union,...
# 270  (In, the, 1990s, ,, work, on, the, Internation...
# 274  (Boris, Yeltsin, ,, president, of, Russia, ,, ...
# 311  (The, influence, of, China, and, India, was, a...
#
#                                               entities     character_entity
# 12   [The Triple Entente, the British Empire, Franc...     [france, russia]
# 13   [Germany, Austria-Hungary, Bulgaria, the Ottom...  [germany, bulgaria]
# 14            [1917, Russia, the Central Powers, Tsar]             [russia]
# 15   [Bolsheviks, the Treaty of Brest-Litovsk, Germ...    [germany, russia]
# 16   [Bolshevik Russia, Baltic, Germany, Kars Oblas...            [germany]
# ..                                                 ...                  ...
# 263                          [the United States, Cuba]               [cuba]
# 265  [a tense week, the Soviet Union, Cold War, the...      [united states]
# 270  [the 1990s, the International Space Station, t...      [russia, japan]
# 274                            [Boris Yeltsin, Russia]             [russia]
# 311                               [China, India, West]              [india]
#
# [95 rows x 3 columns]
