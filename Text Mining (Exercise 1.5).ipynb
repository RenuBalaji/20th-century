# %% [markdown]
# # Text Mining

# %%
# Install the necessary libraries from the requirements.txt file into your corresponding virtual environment. Make sure you start JupyterLab with the extra data rate argument.
from textblob import TextBlob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt  # Corrected typo
import nltk
import re
from collections import Counter

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

sns.set()  # Set Seaborn styles
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/renubalaji/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/renubalaji/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/renubalaji/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Loading the content of the file (Load the twentieth-century data that you scraped in Exercise 1.4.)
file_path = '/Users/renubalaji/Documents/GitHubProjects/20th-century/key_events_20th_century.txt'

with open(file_path, 'r') as file:
    data = file.read()

# Print a snippet of the content
print(data[:1000])  # print the first 1000 characters for preview
# Out:
# Contents
# Historic events in the 20th century
# World at the beginning of the century
# Between the wars
# Global war: World War II (1939–1945)
# The post-war world
# The world at the end of the century
# See also
# References
# Sources
# External links
#
# The 20th century changed the world in unprecedented ways. The World Wars sparked tension between countries and led to the creation of atomic bombs, the Cold War led to the Space Race and the creation of space-based rockets, and the World Wide Web was created. These advancements have played a significant role in citizens' lives and shaped the 21st century into what it is today.
# The new beginning of the 20th century marked significant changes. The 1900s saw the decade herald a series of inventions, including the automobile, airplane and radio broadcasting.
# ...

# %%
# Manually tokenizing the text using regular expressions (Tokenize the words from the text and create a bar chart to plot the 10 most common words.)
tokens = re.findall(r'\b\w+\b', data.lower())

# %%
# Counting the frequency of each word
word_freq = Counter(tokens)

# Getting the 10 most common words
common_words = word_freq.most_common(10)

# Splitting the words and their frequencies for plotting
words, counts = zip(*common_words)

# Creating a bar chart for the 10 most common words
plt.figure(figsize=(10, 6))
plt.bar(words, counts, color='skyblue')
plt.title("Top 10 Most Common Words in 20th Century Events")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Import necessary libraries
import re
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
# Load stop words from NLTK 
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/renubalaji/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove stop words and non-alphabetic tokens (Remove stop words (and punctuation marks if necessary), and rerun the plot. What has changed? Comment on your impressions in a markdown cell under the plot.)
filtered_tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

# Count the frequency of each word
word_freq = Counter(filtered_tokens)

# Get the 10 most common words
common_words = word_freq.most_common(10)

# Split the words and their frequencies for plotting
words, counts = zip(*common_words)

# Create a bar chart for the 10 most common words
plt.figure(figsize=(10, 6))
plt.bar(words, counts, color='skyblue')
plt.title("Top 10 Most Common Words (Stop Words Removed)")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#After removing the stopping words, the words that don't contribute any sense to the analysis are all removed and words which make sense are retained.

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# Download the required NLTK resources (Create a tags list using TextBlob)

from textblob import TextBlob

# Create a TextBlob object
blob = TextBlob(data)

# Generate a list of (word, tag) tuples using TextBlob's part-of-speech tagger
tags = blob.tags

# Display the first 10 tags as an example
print(tags[:10])
# Out:
# [('Contents', 'NNS'), ('Historic', 'JJ'), ('events', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('20th', 'JJ'), ('century', 'NN'), ('World', 'NNP'), ('at', 'IN'), ('the', 'DT')]

# %%
# POS Tagging (Create a list of the Top 10 POS tags for words that appear in the article)
sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                        " ",        # Replace all non-letters with spaces
                        str(filtered_tokens))

# %%
# Word tokenization
from nltk.tokenize import word_tokenize
tokenized_word_2 = word_tokenize(sans_punc)
print (tokenized_word_2)
# Out:
# ['contents', 'historic', 'events', 'century', 'world', 'beginning', 'century', 'wars', 'global', 'war', 'world', 'war', 'ii', 'post', 'war', 'world', 'world', 'end', 'century', 'see', 'also', 'references', 'sources', 'external', 'links', 'century', 'changed', 'world', 'unprecedented', 'ways', 'world', 'wars', 'sparked', 'tension', 'countries', 'led', 'creation', 'atomic', 'bombs', 'cold', 'war', 'led', 'space', 'race', 'creation', 'space', 'based', 'rockets', 'world', 'wide', 'web', 'created', 'advancements', 'played', 'significant', 'role', 'citizens', 'lives', 'shaped', 'century', 'today', 'new', 'beginning', 'century', 'marked', 'significant', 'changes', 'saw', 'decade', 'herald', 'series', 'inventions', 'including', 'automobile', 'airplane', 'radio', 'broadcasting', 'first', 'world', 'war', 'aftermath', 'caused', 'major', 'changes', 'power', 'balance', 'world', 'destroying', 'transforming', 'powerful', 'empires', 'first', 'world', 'war', 'simply', 'wwi', 'termed', 'great', 'war',
# ...

# %%
from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word_2)
print(dist_words)
# Out:
# <FreqDist with 2476 samples and 5952 outcomes>

# %%
dist_words.most_common(10)
# Out:
# [('war', 116),
#  ('world', 58),
#  ('soviet', 49),
#  ('hitler', 40),
#  ('first', 34),
#  ('would', 34),
#  ('germany', 32),
#  ('new', 30),
#  ('states', 29),
#  ('japanese', 29)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
from nltk.probability import FreqDist
from collections import Counter
words = [('war', 116),
 ('world', 58),
 ('soviet', 49),
 ('hitler', 40),
 ('first', 34),
 ('would', 34),
 ('germany', 32),
 ('new', 30),
 ('states', 29),
 ('japanese', 29)]

plt.figure(figsize=(8, 3))
dist_words.plot(10, cumulative=False)  # Correct method call
plt.show()

# %%
# Removing stopwords in words

filtered_tokens = [] # creates an empty list
for words in tokenized_word_2:
      if words not in stop_words:
           filtered_tokens.append(words)

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']

filtered = []
for words in tokenized_word_2:
     if words not in new_stopwords:
        filtered.append(words)

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: user 7.49 ms, sys: 852 µs, total: 8.34 ms
# Wall time: 8.47 ms

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'contents", 'NNS'),
#  ("'", 'POS'),
#  ("'historic", 'NNP'),
#  ("'", 'POS'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'wars", 'NNS'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'ii", 'NNP'),
#  ("'", 'POS'),
#  ("'post", 'FW'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'references", 'NNS'),
#  ("'", 'POS'),
#  ("'sources", 'NNS'),
#  ("'", 'POS'),
#  ("'external", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'changed", 'VBD'),
#  ("'world", 'NNP'),
# ...

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = [ 'Words', "Word type"]
df_t=df_text.groupby('Word type').count().reset_index()
top20=df_t.nlargest(20, 'Words')

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 20):
      sns.barplot(x = "Words", y = "Word type",
     saturation = 0.9, data = top20).set_title("20th century")

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNS")]
df.columns = ["Word", "Occurrences"]
x = df.groupby('Word').count().reset_index()
y = x.sort_values(by = ['Occurrences'], ascending=False)
top10 = y.nlargest(10, 'Occurrences')

# %%
#Plot this list in a bar chart using the seaborn library
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming top10 is a DataFrame with columns "Word" and "Occurrences"
# Example top10 DataFrame structure:
# top10 = pd.DataFrame({'Word': ['war', 'peace', 'freedom'], 'Occurrences': [20, 15, 10]})

plt.figure(figsize=(10, 5))

# Set a custom Seaborn color palette
sns.set_palette(sns.xkcd_palette(["blue", "green", "red", "orange", "purple"]))

# Create the barplot
sns.barplot(x="Word", y="Occurrences", data=top10, saturation=0.9).set_title("The 20th Century")

# Show the plot
plt.show()

# %%
listToStr = ' '.join([str(elem) for elem in filtered])

print(listToStr)
# Out:
# contents historic events century world beginning century wars global war world war ii post war world world end century see also references sources external links century changed world unprecedented ways world wars sparked tension countries led creation atomic bombs cold war led space race creation space based rockets world wide web created advancements played significant role citizens lives shaped century today new beginning century marked significant changes saw decade herald series inventions including automobile airplane radio broadcasting first world war aftermath caused major changes power balance world destroying transforming powerful empires first world war simply wwi termed great war contemporaries started ended war extension century whole ignited assassination sarajevo austro hungarian empire heir throne erzherzog franz ferdinand gavrilo princip organization young bosnia bosnian serbs liberation movement similar inciting incident century bound slavic nationalism help small s
# ...

# %%
# Create a count for the main characters

all_counts = Counter(re.sub(r'\W+', ' ', listToStr).split())

# %%
import pandas as pd

# Example DataFrame
chars = pd.DataFrame({
    'character': ['Gavrilo Princip', 'Adolf Hitler', 'Joseph Stalin', 'Winston Churchill']
})

# Perform multiple name replacements using a dictionary
chars['character'] = chars['character'].replace({
    'Gavrilo Princip': 'Gavrilo',
    'Adolf Hitler': 'Hitler',
    'Joseph Stalin': 'Stalin',
    'Winston Churchill': 'Churchill'
})

print(chars)

chars['character'] = chars['character'].replace('Gavrilo Princip','Gavrilo')
chars['character'] = chars['character'].replace('Adolf Hitler','Hitler')
chars['character'] = chars['character'].replace('Joseph Stalin','Stalin')
chars['character'] = chars['character'].replace('Winston Churchill','Churchill')
# Out:
#    character
# 0    Gavrilo
# 1     Hitler
# 2     Stalin
# 3  Churchill

# %%
chars['character_alias'] = chars['character'].apply(lambda x: x.rsplit(' ',1)[-1])

# %%
chars_list = chars['character_alias'].to_list()

# %%
dict_of_counts = {d : all_counts[d] for d in chars_list}

# %%
#Search for the names from the list in the dictionary

dct = {v:[k] for v,k in dict_of_counts.items()}
df = pd.DataFrame(dct)

# %%
text_sent = TextBlob(str(filtered))
print(text_sent.sentiment)
# Out:
# Sentiment(polarity=0.03955024916943524, subjectivity=0.3530823604689881)

# %%
#Create three bar plots with the top 15 POS labels—one each for nouns, verbs, and adjectives. Analyzing the results—what do you think stands out in these frequencies? 
import matplotlib.pyplot as plt
from collections import Counter

# The tag list you've provided (shortened for clarity, but use the entire list)
tagged_tokens = [
    ('contents', 'NNS'), ('contents', 'NNS'), ('historic', 'NNP'),
    ('events', 'NNS'), ('century', 'NNP'), ('world', 'NNP'),
    ('beginning', 'VBG'), ('century', 'NNP'), ('wars', 'NNS'),
    ('war', 'NNP'), ('world', 'NNP'), ('war', 'NNP'),
    ('ii', 'NNP'), ('post', 'FW'), ('war', 'NNP'), ('world', 'NNP'),
    ('world', 'NNP'), ('century', 'NNP'), ('see', 'NNP'), 
    ('also', 'NNP'), ('references', 'NNS'), ('sources', 'NNS'),
    ('external', 'NNP'), ('links', 'NNS'), ('century', 'NNP'), 
    ('changed', 'VBD'), ('world', 'NNP'), ('unprecedented', 'VBD'),
    ('ways', 'NNS'), ('world', 'NNP'), ('wars', 'NNS'),
    ('sparked', 'VBD'), ('tension', 'NNP'), ('countries', 'NNS'),
    ('led', 'VBD'), ('creation', 'NNP'), ('atomic', 'NNP'),
    ('war', 'NNP'), ('led', 'VBD'), ('space', 'NNP'), 
    ('race', 'NNP'), ('creation', 'NN'), ('space', 'NNP'), 
    ('based', 'VBD'), ('rockets', 'NNS'), ('world', 'NNP'),
    ('wide', 'NNP'), ('web', 'NNP'), ('created', 'VBD'), 
    ('advancements', 'NNS'), ('significant', 'NNP'), 
    ('role', 'NNP'), ('citizens', 'NNS'), ('lives', 'NNS'),
    ('shaped', 'VBD'), ('century', 'NNP'), ('new', 'NNP'), 
    ('beginning', 'VBG'), ('century', 'NNP'), ('marked', 'VBD'), 
    ('significant', 'NNP'), ('changes', 'NNS'), ('saw', 'NNP'), 
    ('herald', 'NNP'), ('series', 'NNS'), ('inventions', 'NNS'),
    ('including', 'VBG'), ('automobile', 'IN'), ('airplane', 'NNP'),
    ('radio', 'NNP'), ('broadcasting', 'VBG'), ('first', 'NNP'),
    ('world', 'NNP'), ('war', 'NNP'), ('aftermath', 'NNP'), 
    ('caused', 'VBD'), ('changes', 'NNS'), ('power', 'NNP'),
    ('balance', 'NN'), ('world', 'NNP'), ('destroying', 'VBG'), 
    ('transforming', 'VBG'), ('empires', 'NNS'), ('first', 'NNP'),
    ('world', 'NNP'), ('war', 'NNP'), ('simply', 'NNP'), 
    ('wwi', 'NNP'), ('termed', 'VBD'), ('great', 'NNP'), 
    ('war', 'NNP'), ('contemporaries', 'NNS'), ('started', 'VBD'), 
    ('ended', 'VBD'), ('war', 'NNP'), ('extension', 'NN'), 
    ('century', 'NNP'), ('whole', 'NNP'), ('ignited', 'VBD'), 
    ('assassination', 'NNP'), ('sarajevo', 'NNP'), 
    ('austro', 'NNP'), ('hungarian', 'JJ'), ('empire', 'NNP'),
    ('throne', 'CD'), ('erzherzog', 'NNP'), ('franz', 'NNP'),
    ('ferdinand', 'NNP'), ('gavrilo', 'NNP'), ('princip', 'NNP'),
    ('organization', 'NN'), ('young', 'NNP'), ('bosnia', 'NNP'), 
    ('bosnian', 'JJ'), ('serbs', 'NNP'), ('liberation', 'NN'), 
    ('movement', 'NNP'), ('inciting', 'VBG'), ('incident', 'NNP'),
    ('century', 'NNP'), ('bound', 'IN'), ('slavic', 'NNP'), 
    ('nationalism', 'NN'), ('small', 'DT'), ('serbian', 'JJ'),
    ('state', 'NNP'), ('russians', 'NNS'), ('aid', 'NNP'), 
    ('serbs', 'NNP'), ('attacked', 'VBD'), ('alliances', 'NNS'),
    ('increasing', 'VBG'), ('arms', 'NNS'), ('race', 'NNP'), 
    ('hatreds', 'NNS'), ('dragged', 'VBD'), ('war', 'NNP'), 
    ('allies', 'NNS'), ('initially', 'RB'), ('entente', 'NNP'), 
    ('comprised', 'VBD'), ('empire', 'NNP'), ('france', 'NN'), 
    ('austria', 'NNP'), ('hungary', 'NNP'), ('bulgaria', 'NNP'),
    ('later', 'NNP'), ('ottoman', 'NNP'), ('empire', 'NNP'),
    ('central', 'NNP'), ('powers', 'NNS'), ('ended', 'VBD'),
    ('hostile', 'IN'), ('actions', 'NNS'), ('central', 'NNP'),
    ('powers', 'NNS'), ('tsar', 'NNP'), ('bolsheviks', 'NNP'),
    ('negotiated', 'VBD'), ('treaty', 'NNP'), ('brest', 'JJS'),
    ('litovsk', 'NNP'), ('although', 'IN'), ('cost', 'FW'),
    ('treaty', 'NNP'), ('bolshevik', 'NNP'), ('ceded', 'VBD'),
    ('baltic', 'JJ'), ('states', 'VBZ'), ('province', 'NN'),
    ('kars', 'NNS'), ('south', 'NNP'), ('caucasus', 'NNP'), 
    ('ottoman', 'NNP'), ('also', 'NNP'), ('recognized', 'VBN'),
    ('independence', 'NNP'), ('ukraine', 'NNP'), ('shifted', 'VBD'),
    ('forces', 'NNS'), ('eastern', 'NNP'), ('western', 'NNP'), 
    ('front', 'NNP'), ('signing', 'VBG'), ('treaty', 'NNP'), 
    ('unable', 'JJ'), ('stop', 'NNP'), ('allied', 'VBD'), 
    ('advance', 'NNP'), ('entrance', 'NN'), ('american', 'JJ'),
    ('troops', 'NNS'), ('war', 'NNP'), ('chance', 'NN'), 
    ('combatant', 'NNP'), ('nations', 'NNS'), ('show', 'NNP'), 
    ('military', 'NNP'), ('strength', 'NNP'), ('germans', 'NNS'), 
    ('introduced', 'VBD'), ('machine', 'NNP'), ('gun', 'NNP'),
    ('boats', 'NNS'), ('deadly', 'RB'), ('gases', 'NNS')
]

# Extract nouns, verbs, and adjectives
nouns = [token for token, pos in tagged_tokens if pos.startswith('NN')]  # Nouns (NN, NNS, NNP, etc.)
verbs = [token for token, pos in tagged_tokens if pos.startswith('VB')]  # Verbs (VB, VBD, VBG, etc.)
adjectives = [token for token, pos in tagged_tokens if pos == 'JJ']      # Adjectives (JJ)

# Get the top 15 most common nouns, verbs, and adjectives
top_nouns = Counter(nouns).most_common(15)
top_verbs = Counter(verbs).most_common(15)
top_adjectives = Counter(adjectives).most_common(15)

# Function to plot bar chart
def plot_bar_chart(items, title, xlabel):
    tokens, counts = zip(*items)
    plt.figure(figsize=(10, 5))
    plt.bar(tokens, counts, color='blue')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# Plot the top 15 Nouns
plot_bar_chart(top_nouns, 'Top 15 Nouns', 'Nouns')

# Plot the top 15 Verbs
plot_bar_chart(top_verbs, 'Top 15 Verbs', 'Verbs')

# Plot the top 15 Adjectives
plot_bar_chart(top_adjectives, 'Top 15 Adjectives', 'Adjectives')

# %% [markdown]
# Nouns are most commonly used with frequencies higher than verbs or adjectives. In nouns, the most common noun that has been mentioned with the highest frequency is world and war. In verbs, beginning is the highest used verb. In adjectives, hungarian is the most frequent word.

# %%
#Create a dataframe with the countries and the number of times they’re mentioned in your text (remember—you’ll need to use the countries lookup list if you didn’t scrape one in the previous task).

import pandas as pd
from collections import Counter
import string
import matplotlib.pyplot as plt

# Sample text (replace this with your actual text)
text = """
contents historic events century world beginning century wars global war world war ii post war world world end century see also references sources external links century changed world unprecedented ways world wars sparked tension countries led creation atomic bombs cold war led space race creation space based rockets world wide web created advancements played significant role citizens lives shaped century today new beginning century marked significant changes saw decade herald series inventions including automobile airplane radio broadcasting first world war aftermath caused major changes power balance world destroying transforming powerful empires first world war simply wwi termed great war contemporaries started ended war extension century whole ignited assassination sarajevo austro hungarian empire heir throne erzherzog franz ferdinand gavrilo princip organization young bosnia bosnian serbs liberation movement similar inciting incident century bound slavic nationalism help small serbian state russians came aid serbs attacked interwoven alliances increasing arms race old hatreds dragged europe war allies known initially triple entente comprised british empire france russia germany austria hungary bulgaria later ottoman empire known central powers russia ended hostile actions central powers fall tsar bolsheviks negotiated treaty brest litovsk germany although huge cost russia treaty bolshevik russia ceded baltic states germany province kars oblast south caucasus ottoman empire also recognized independence ukraine although germany shifted huge forces eastern western front signing treaty unable stop allied advance especially entrance american troops war also chance combatant nations show military strength technological ingenuity germans introduced machine gun u boats deadly gases british first used tank sides chance test new aircraft see could used warfare widely believed war would short unfortunately since trench warfare best form defense advances sides slow came terrible cost lives war finally results would set stage next twenty years first foremost germans forced sign treaty versailles forcing make exorbitant payments repair damages caused war many germans felt reparations unfair actually lose war feel caused war see stab back legend germany never occupied allied troops yet accept liberal democratic government imposed victors abdication kaiser wilhelm much map europe redrawn victors based upon theory future wars could prevented ethnic groups homeland new states like yugoslavia czechoslovakia created former austro hungarian empire accommodate nationalist aspirations groups international body called league nations formed mediate disputes prevent future wars although effectiveness severely limited among things reluctance inability act russian revolution ending overthrow tsarist regime execution imperial majesty nicholas ii family sparked wave communist revolutions across europe prompting many believe socialist world revolution could realized near future however european revolutions defeated vladimir lenin died within years joseph stalin displaced leon trotsky de facto leader soviet union idea worldwide revolution longer forefront stalin concentrated socialism one country embarked bold plan collectivization industrialization majority socialists even many communists became disillusioned stalin autocratic rule purges assassination enemies well news famines imposed people communism strengthened force western democracies global economy crashed
liation gone north proceeded violate ceasefire invaded south full military force saigon captured april vietnam unified communist rule year later effectively bringing end one unpopular wars time cuban missile crisis illustrates close brink nuclear war world came cold war cuba fidel castro socialist government formed close ties soviet union obviously disquieting united states given cuba proximity lockheed u spy plane flights island revealed soviet missile launchers installed u president john f kennedy instituted naval blockade publicly confronted soviet union tense week soviet union backed ordered launchers removed wanting risk igniting new world war cold war tensions running high soviet union united states took rivalry stars soviet launch sputnik space race two powers followed ussr reached several important milestones first craft moon luna first human space yuri gagarin u pulled ahead eventually mercury gemini apollo programs culminated apollo astronauts landing moon july five landings astronauts followed apollo forced abort mission nevertheless despite successes u space program could match many major achievements soviet space program rover based space exploration image video transfer surface another planet early century addition countries launched numerous probes space venera voyager later decades space became somewhat friendlier place regular space flights astronauts made possible american space shuttle first reusable spacecraft successfully used mir skylab enabled prolonged human habitation space work international space station began end century still incomplete continual use astronauts united states europe russia japan canada soviet union weakening sino soviet split removed ussr powerful ally people republic china arms race u draining country funds weakened internal pressures ethnic political mikhail gorbachev last leader attempted reform country glasnost perestroika formation solidarity fall berlin wall breaking several soviet republics lithuania started slippery slope events culminated coup overthrow gorbachev organized communist party hard liners boris yeltsin president russia organized mass opposition coup failed december soviet union officially disbanded constituent republics thus putting final line already exhausted cold war creation transistor revolutionized development computer first computers room sized electro mechanical devices built break cryptographical codes world war ii quickly became least times smaller using transistors computers became reprogrammable rather fixed purpose devices invention programming languages meant computer operators could concentrate problem solving high level without think terms individual instructions computer creation operating systems also vastly improved programming productivity building computer pioneers could realize envisioned graphical user interface piloted computer mouse made simple harness power computer made accessible new users storage computer programs progressed punched cards paper tape magnetic tape floppy disks hard disks core memory bubble memory fell random access memory invention word processor spreadsheet database greatly improved office productivity old paper typewriter filing cabinet methods economic advantage given businesses led economic efficiencies computers cost effective cpus led thousands industrial home brew computer designs many became successful home computer boom led apple ii commodore pet ibm seeking embrace microcomputer revolution devised ibm personal computer pc crucially ibm developed pc third party components available open market impediment another company duplicating system architecture proprietary bios software companies starting compaq reverse engineered bios released pc compatible computers soon became dominant architecture microsoft produced operating system pc rode wave popularity become world leading software company heralded information age rise computer applications data processing made ethereal information valuable physical commodities brought new concerns surrounding intellectual property issues u government made algorithms patentable forming basis software patents controversy proprietary software led richard stallman create free software foundation begin gnu project paving way free software movement computers also became usable platform entertainment computer games first developed software programmers exercising creativity large systems universities efforts became commercially successful arcade games pong space invaders home computer market established young programmers bedrooms became core youthful video game industry order take advantage advancing technology games consoles created like arcade systems machines custom hardware designed game oriented operations sprites parallax scrolling preference general purpose computing tasks computer networks appeared two main styles local area network linking computers office school wide area network linking local area networks together initially computers depended telephone networks link spawning bulletin board sub culture however darpa project create bomb proof computer networks led creation internet network networks core network robust tcp ip network protocol thanks efforts al gore internet grew beyond military role universities commercial businesses permitted connect networks main impetus electronic mail far faster convenient form communication conventional letter memo distribution file transfer protocol ftp however internet remained largely unknown general public used bulletin boards services like compuserve america online changed tim berners lee devised simpler form vannevar bush hypertext dubbed world wide web web suddenly changed internet printing press beyond geographic boundaries physical countries termed cyberspace anyone computer internet connection could write pages simple html format publish thoughts world web immense success also fueled commercial use internet convenient home shopping element visions future since development telephone race provide convenient interactive consumerism companies trading websites became known dot coms due com suffix commercial internet addresses change century also lead fear paranoia hypothesized world computers would glitch cause havoc banks prisons transit systems end century technological advances scientific discoveries made preceding history communications information technology transportation technology medical advances radically altered daily lives europe appeared sustainable peace first time recorded history people indian subcontinent sixth world population end century attained indigenous independence first time centuries china ancient nation comprising fifth world population finally open world new powerful synthesis west east creating new state near complete destruction old cultural order end colonialism cold war nearly billion people africa left truly independent new nation states cut whole cloth standing centuries foreign domination world undergoing second major period globalization first started century terminated world war since us position almost unchallenged domination major part process americanization led anti western anti american feelings parts world especially middle east influence china india also rising world largest populations long marginalized west rulers rapidly integrating world economy however several problems face world gap rich poor nations continued widen said problem could fixed set amount wealth could shared many others said powerful nations large economies enough help improve rapidly evolving economies third world however developing countries faced many challenges including scale task surmounted rapidly growing populations need protect environment cost goes along terrorism dictatorship spread nuclear weapons issues requiring attention world still blighted small scale wars violent conflicts fueled competition resources ethnic conflicts despots kim jong il north korea continued lead nations toward development nuclear weapons disease threatened destabilize many regions world new viruses sars west nile continued spread poor nations malaria diseases affected majority population millions infected hiv virus causes aids virus becoming epidemic southern africa perhaps importantly speculated long term environmental problems threatened planet livability serious problem global warming predicted frequently flood coastal areas due human caused emission greenhouse gases particularly carbon dioxide produced burning fossil fuels like threat nuclear world war shift climate change since added fear possibility human extinction although overnight several decades prompted many nations negotiate sign kyoto treaty set mandatory limits carbon dioxide emissions celebration century ending expressed popular opinion new year eve new year day marked turn millennium strictly speaking century ended new year eve century began new year day
"""

# Tokenize the text and clean it
tokens = [token.strip(string.punctuation).lower() for token in text.split()]

# Static list of country names (make sure all names are in lowercase for matching)
countries = [
    'germany', 'austria-hungary', 'ottoman empire', 'united states', 'france', 
    'russia', 'japan', 'soviet union', 'serbia', 'bosnia', 'hungary', 'italy', 'united kingdom'
]

# Find and count the countries mentioned in the text
mentioned_countries = [token for token in tokens if token in countries]
country_counts = Counter(mentioned_countries)

# Convert the country counts to a DataFrame
df_countries = pd.DataFrame(country_counts.items(), columns=['Country', 'Mentions'])

# Sort the DataFrame by the number of mentions
df_countries = df_countries.sort_values(by='Mentions', ascending=False)

print (df_countries)
# Out:
#    Country  Mentions
# 3  germany        32
# 6    japan        26
# 1   france        14
# 2   russia         8
# 5    italy         8
# 4  hungary         2
# 0   bosnia         1

# %%
#Create a plot showing the frequency of the number of times these countries are mentioned in the text. Is there anything in particular you notice in this plot?
# Plotting the frequency of mentions
plt.figure(figsize=(10, 5))
plt.bar(df_countries['Country'], df_countries['Mentions'], color='skyblue')
plt.title('Frequency of Country Mentions in the Text')
plt.xlabel('Country')
plt.ylabel('Number of Mentions')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.show()

# %% [markdown]
# Germany is mentioned the most, with around 30 mentions.
# Japan follows with approximately 25 mentions.
# France has about 15 mentions.
# Russia and Italy have fewer mentions, around 10 and 7 respectively.
# Hungary and Bosnia are mentioned the least, with around 2-3 mentions each.
#
# There seems to be a clear pattern where Germany and Japan are significantly more mentioned than the rest of the countries in the text
